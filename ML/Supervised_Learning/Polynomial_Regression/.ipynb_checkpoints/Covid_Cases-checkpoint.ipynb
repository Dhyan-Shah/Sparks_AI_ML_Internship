# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('./covid_cases.csv')

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Days']=(
    df['Date']-df['Date'].min()
).dt.days

# %%
X=df[['Days']]
y=df['Cases']

# %%
for i in range(1,6):
    poly=PolynomialFeatures(degree=i)
    x_poly=poly.fit_transform(X)
    model=LinearRegression()
    model.fit(x_poly,y)
    y_pred=model.predict(x_poly)
    print(f'{i}: {metrics.r2_score(y,y_pred)}')
# Out:
# 1: 0.9995759497602076
# 2: 0.999576030325016
# 3: 0.9995835444931465
# 4: 0.999603324356539
# 5: 0.9988995418875906

# %%
poly=PolynomialFeatures(degree=4)
x_poly=poly.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(
    x_poly,y,test_size=0.2,random_state=42
)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f'R2 score: {metrics.r2_score(y_pred,y_test)}')
# Out:
# R2 score: 0.9994974484639718

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.scatter(
    X,
    y,
    alpha=0.5,
    label='Actual Cases'
)

plt.plot(
    X,
    model.predict(x_poly),
    color='red',
    linewidth=3,
    label='Polynomial Regression'
)

plt.xlabel('Days')

plt.ylabel('Cases')

plt.title('COVID Cases Forecasting')

plt.legend()

plt.show()
