# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %%
df=pd.read_csv('./RealEstate.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.head
# Out:
# <bound method NDFrame.head of       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]>

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
X = df[["X2 house age","X3 distance to the nearest MRT station","X4 number of convenience stores","X5 latitude","X6 longitude"]]
y = df["Y house price of unit area"]
for i in range(1,10):
    poly = PolynomialFeatures(degree=i)
    x_poly = poly.fit_transform(X)
    model = LinearRegression()
    model.fit(x_poly,y)
    y_pred = model.predict(x_poly)
    print(f"R2_Score Or Accuracy : {i} {metrics.r2_score(y_pred,y)} ")
# Out:
# R2_Score Or Accuracy : 1 0.24918234424700103
# R2_Score Or Accuracy : 2 0.5438331806443681
# R2_Score Or Accuracy : 3 0.6074423361991306
# R2_Score Or Accuracy : 4 0.6351367750386192
# R2_Score Or Accuracy : 5 0.6387171786401151
# R2_Score Or Accuracy : 6 0.6072676671226211
# R2_Score Or Accuracy : 7 0.5220818916486837
# R2_Score Or Accuracy : 8 0.37738686162247026
# R2_Score Or Accuracy : 9 0.2697387952686432

# %%
poly = PolynomialFeatures(degree=5)
x_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(x_poly,y)
y_pred = model.predict(x_poly)
print("MAE: ",metrics.mean_absolute_error(y,y_pred))
print("MSE: ",metrics.mean_squared_error(y,y_pred))
print("R2 Score: ",metrics.r2_score(y,y_pred))
# Out:
# MAE:  4.431448017961344
# MSE:  49.01679301656003
# R2 Score:  0.7345986568654411
