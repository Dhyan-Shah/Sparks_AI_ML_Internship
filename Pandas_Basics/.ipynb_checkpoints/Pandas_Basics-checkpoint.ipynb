# %% [markdown]
# # Pandas Basics

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
s=pd.Series([1,2,3,'A',np.nan], index=['x','y','z','a','b'])
s
students_name=['Dhyan','Raj','Krush','Sujal','Rudra']
marks=[100,90,80,70,60]
s=pd.Series(marks,index=students_name,name='Students_Marks')
s
# Out:
# Dhyan    100
# Raj       90
# Krush     80
# Sujal     70
# Rudra     60
# Name: Students_Marks, dtype: int64

# %%
df=pd.read_csv('bollywood.csv')
df.shape
df
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]>

# %%
df.head
# Out:
# <bound method NDFrame.head of                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]>

# %%
df2=pd.read_csv('subs.csv')
df2.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
df2.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
df2.min()
# Out:
# Subscribers gained    33
# dtype: int64

# %%
df2.max()
# Out:
# Subscribers gained    396
# dtype: int64

# %%
df=df.squeeze()
df
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
df[-5:]
# Out:
#                        movie              lead
# 1495  Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496     Aankhen (2002 film)  Amitabh Bachchan
# 1497         Saathiya (film)      Vivek Oberoi
# 1498          Company (film)        Ajay Devgn
# 1499    Awara Paagal Deewana      Akshay Kumar

# %%
df[::2]
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 4                          Evening Shadows  Mona Ambegaonkar
# 6                            Fraud Saiyaan      Arshad Warsi
# 8         Manikarnika: The Queen of Jhansi    Kangana Ranaut
# ...                                    ...               ...
# 1490                      Raaz (2002 film)        Dino Morea
# 1492            Waisa Bhi Hota Hai Part II      Arshad Warsi
# 1494                                Kaante  Amitabh Bachchan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1498                        Company (film)        Ajay Devgn
#
# [750 rows x 2 columns]

# %%
'Alia Bhatt' in df.values
# Out:
# True

# %%
counts = df['lead'].value_counts()

print(f'Actors with more than 20 movies: {counts[counts > 20]}')
# Out:
# Actors with more than 20 movies: lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# movie                     lead
# Tanu Weds Manu: Returns   Kangana Ranaut      2
# Gabbar Is Back            Akshay Kumar        2
# Andaaz                    Akshay Kumar        2
# Uri: The Surgical Strike  Vicky Kaushal       1
# Battalion 609             Vicky Ahuja         1
#                                              ..
# Hum Tumhare Hain Sanam    Shah Rukh Khan      1
# Aankhen (2002 film)       Amitabh Bachchan    1
# Saathiya (film)           Vivek Oberoi        1
# Company (film)            Ajay Devgn          1
# Awara Paagal Deewana      Akshay Kumar        1
# Name: count, Length: 1497, dtype: int64

# %%
df.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
df[df['movie']=='Andaaz']
# Out:
#        movie          lead
# 1417  Andaaz  Akshay Kumar
# 1418  Andaaz  Akshay Kumar

# %%
df.iloc[[1417,1418]]
# Out:
#        movie          lead
# 1417  Andaaz  Akshay Kumar
# 1418  Andaaz  Akshay Kumar

# %%
df.isnull().sum()
# Out:
# movie    0
# lead     0
# dtype: int64

# %%
df[df['movie'].duplicated()]
# Out:
#                         movie            lead
# 358   Tanu Weds Manu: Returns  Kangana Ranaut
# 368            Gabbar Is Back    Akshay Kumar
# 1418                   Andaaz    Akshay Kumar

# %%
df.shape
# Out:
# (1500, 2)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1497, 2)
